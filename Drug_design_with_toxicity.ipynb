# %%
# !pip install tensorflow rdkit-pypi gym
# Out:
# ...
#   Obtaining dependency information for rdkit-pypi from https://files.pythonhosted.org/packages/65/61/f38bf03fb4060076aa955a62812de3176add23df7a8fbda2e2889316f4a6/rdkit_pypi-2022.9.5-cp311-cp311-macosx_10_9_x86_64.whl.metadata
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.7/721.7 kB 5.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Obtaining dependency information for gym-notices>=0.0.4 from https://files.pythonhosted.org/packages/25/26/d786c6bec30fe6110fd3d22c9a273a2a0e56c0b73b93e25ea1af5a53243b/gym_notices-0.0.8-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 2.2 MB/s eta 0:00:0000:0100:01m
# ...
#   Created wheel for gym: filename=gym-0.26.2-py3-none-any.whl size=827620 sha256=d75abe4ca893fe87faa9f27e0be837add9b5e5983d4d0ea8ddbf27f9ec7ad73e
# ...

# %% [markdown]
# # Ethane

# %% [markdown]
# imports

# %%
import gym
from gym import spaces
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem, Descriptors
from rdkit.Chem.QED import qed
import tensorflow as tf
from tensorflow.keras import layers
# Out:
# 2024-05-26 15:43:33.750365: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Environment

# %%
class MoleculeEnv(gym.Env):
    def __init__(self):
        super(MoleculeEnv, self).__init__()
        self.action_space = spaces.Discrete(4)  # Define 4 actions for simplicity
        self.observation_space = spaces.Box(low=0, high=1, shape=(100,), dtype=np.float32)
        self.current_molecule = None
        self.reset()

    def reset(self):
        self.current_molecule = Chem.MolFromSmiles('CC')  # Start with a simple ethane molecule
        return self._get_observation()

    def step(self, action):
        self._take_action(action)
        reward = self._compute_reward()
        done = self._is_done()
        obs = self._get_observation()
        return obs, reward, done, {}

    def _take_action(self, action):
        # Modify the molecule based on the action
        if action == 0:
            self.current_molecule = Chem.AddHs(self.current_molecule)  # Add hydrogen atoms
        elif action == 1:
            self.current_molecule = Chem.RemoveHs(self.current_molecule)  # Remove hydrogen atoms
        elif action == 2:
            self.current_molecule = self._modify_molecule(self._add_carbon_chain)  # Add a carbon chain
        elif action == 3:
            self.current_molecule = self._modify_molecule(self._remove_carbon_chain)  # Remove a carbon chain

    def _modify_molecule(self, modification_func):
        # Apply the modification and ensure it's valid
        mol = modification_func(self.current_molecule)
        if mol is not None:
            return mol
        return self.current_molecule

    def _add_carbon_chain(self, mol):
        # Add a carbon chain to the molecule
        try:
            mol = Chem.RWMol(mol)
            ethane = Chem.MolFromSmiles('CC')
            mol = Chem.CombineMols(mol, ethane)
            smi = AllChem.MolToSmiles(mol)
            return Chem.MolFromSmiles(smi)
        except ValueError:
            return None


    def _remove_carbon_chain(self, mol):
        # Remove a carbon chain from the molecule
        try:
            smi = Chem.MolToSmiles(mol)
            if 'CC' in smi:
                smi = smi.replace('CC', '', 1)
                return Chem.MolFromSmiles(smi)
            return None
        except ValueError:
            return None

    def _get_observation(self):
        return np.array(AllChem.GetMorganFingerprintAsBitVect(self.current_molecule, 2, nBits=100), dtype=np.float32)

    def _compute_reward(self):
        # Reward based on QED score (placeholder for binding affinity with JAK2)
        try:
            return qed(self.current_molecule)
        except:
            return 0.0

    def _is_done(self):
        # Done if the molecule has more than 50 heavy atoms
        return self.current_molecule.GetNumHeavyAtoms() > 50

# %% [markdown]
# Agent

# %%
class ActorCritic(tf.keras.Model):
    def __init__(self, action_space):
        super(ActorCritic, self).__init__()
        self.dense1 = layers.Dense(128, activation='relu')
        self.dense2 = layers.Dense(128, activation='relu')
        self.actor = layers.Dense(action_space, activation='softmax')
        self.critic = layers.Dense(1, activation='linear')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.actor(x), self.critic(x)

# %%
env = MoleculeEnv()
model = ActorCritic(action_space=env.action_space.n)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
def compute_loss(action_probs, values, rewards):
    advantage = rewards - values
    actor_loss = -tf.math.log(action_probs) * advantage
    critic_loss = tf.square(advantage)
    return tf.reduce_mean(actor_loss + critic_loss)

@tf.function
def train_step(state, action, reward, next_state, done):
    state = tf.convert_to_tensor([state], dtype=tf.float32)
    next_state = tf.convert_to_tensor([next_state], dtype=tf.float32)
    action = tf.convert_to_tensor([action], dtype=tf.int32)
    reward = tf.convert_to_tensor([reward], dtype=tf.float32)
    done = tf.convert_to_tensor([done], dtype=tf.float32)

    with tf.GradientTape() as tape:
        action_probs, value = model(state)
        _, next_value = model(next_state)

        action_prob = tf.reduce_sum(action_probs * tf.one_hot(action, env.action_space.n), axis=1)
        td_target = reward + (1 - done) * next_value
        td_error = td_target - value
        loss = compute_loss(action_prob, value, reward)

    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %%
num_episodes = 500
for episode in range(num_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state = np.expand_dims(state, axis=0)
        action_probs, _ = model(state)
        action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
        next_state, reward, done, _ = env.step(action)
        train_step(state[0], action, reward, next_state, done)
        state = next_state
        episode_reward += reward

    print(f'Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

print("Training finished!")
# Out:
# WARNING:tensorflow:5 out of the last 7 calls to <function train_step at 0x7c087873ca60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
def test_model(env, model, num_episodes=10):
    total_rewards = []
    for episode in range(num_episodes):
        state = env.reset()
        done = False
        episode_reward = 0

        while not done:
            state = np.expand_dims(state, axis=0)
            action_probs, _ = model(state)
            action = np.argmax(action_probs[0])  # Choose the action with the highest probability
            next_state, reward, done, _ = env.step(action)
            state = next_state
            episode_reward += reward

        total_rewards.append(episode_reward)
        print(f'Test Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

    avg_reward = np.mean(total_rewards)
    print(f'Average Reward over {num_episodes} test episodes: {avg_reward}')

# %%
# Testing the trained model
print("Testing the trained model...")
test_model(env, model, num_episodes=10)
# Out:
# Testing the trained model...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-6ebce937e6f2> in <cell line: 3>()
#       1 # Testing the trained model
#       2 print("Testing the trained model...")
# ----> 3 test_model(env, model, num_episodes=10)
#
# <ipython-input-25-e7f7d45b43e6> in test_model(env, model, num_episodes)
#       8         while not done:
#       9             state = np.expand_dims(state, axis=0)
# ---> 10             action_probs, _ = model(state)
#      11             action = np.argmax(action_probs[0])  # Choose the action with the highest probability
#      12             next_state, reward, done, _ = env.step(action)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
# ...

# %%
# Inside the training loop
num_episodes = 50
highest_qed_molecule = None
highest_qed_score = -float('inf')

for episode in range(num_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state = np.expand_dims(state, axis=0)
        action_probs, _ = model(state)
        action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
        next_state, reward, done, _ = env.step(action)
        train_step(state[0], action, reward, next_state, done)
        state = next_state
        episode_reward += reward

        # Print current molecule and its QED score
        current_qed_score = env._compute_reward()  # Calculate QED score of the current molecule
        current_smiles = Chem.MolToSmiles(env.current_molecule)
        # print(f'Current Molecule (SMILES): {current_smiles}, Current QED Score: {current_qed_score}')

    # Print episode statistics
    print(f'Training Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

    # Check if the QED score of the current molecule is higher than the highest QED score encountered so far
    if current_qed_score > highest_qed_score:
        highest_qed_score = current_qed_score
        highest_qed_molecule = env.current_molecule

# Print the highest QED molecule and its score after training
if highest_qed_molecule is not None:
    highest_qed_smiles = Chem.MolToSmiles(highest_qed_molecule)
    print(f'Highest QED Molecule (SMILES): {highest_qed_smiles}')
    print(f'Highest QED Score: {highest_qed_score}')
else:
    print("No molecule with a positive QED score encountered during training.")
# Out:
# [16:30:01] SMILES Parse Error: syntax error while parsing: .CC.CC.CC
# [16:30:01] SMILES Parse Error: Failed parsing SMILES '.CC.CC.CC' for input: '.CC.CC.CC'
# [16:30:01] SMILES Parse Error: syntax error while parsing: .CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC
# [16:30:01] SMILES Parse Error: Failed parsing SMILES '.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC' for input: '.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC'
# [16:30:01] SMILES Parse Error: syntax error while parsing: .CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC
# [16:30:01] SMILES Parse Error: Failed parsing SMILES '.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC' for input: '.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC'
# [16:30:01] SMILES Parse Error: syntax error while parsing: .CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC
# [16:30:01] SMILES Parse Error: Failed parsing SMILES '.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC' for input: '.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC.CC'
# ...

# %% [markdown]
# # Aspirin

# %%
import numpy as np
import gym
from gym import spaces
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import QED
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import ast

# %%
class MoleculeEnv(gym.Env):
    def __init__(self):
        super(MoleculeEnv, self).__init__()
        self.action_space = spaces.Discrete(4)  # Define 4 actions for simplicity
        self.observation_space = spaces.Box(low=0, high=1, shape=(100,), dtype=np.float32)
        self.current_molecule = None
        self.good_qed_molecules = []  # Track of molecules with good QED scores
        self.reset()

    def reset(self):
        self.current_molecule = Chem.MolFromSmiles('CC')  # Start with a simple ethane molecule
        return self._get_observation()

    def step(self, action):
        self._take_action(action)
        reward = self._compute_reward()
        done = self._is_done()
        obs = self._get_observation()
        return obs, reward, done, {}

    def _take_action(self, action):
        # Modify the molecule based on the action
        if action == 0:
            self.current_molecule = Chem.AddHs(self.current_molecule)  # Add hydrogen atoms
        elif action == 1:
            self.current_molecule = Chem.RemoveHs(self.current_molecule)  # Remove hydrogen atoms
        elif action == 2:
            self.current_molecule = self._modify_molecule(self._add_aspirin_chain)  # Add an aspirin chain
        elif action == 3:
            self.current_molecule = self._modify_molecule(self._remove_aspirin_chain)  # Remove an aspirin chain

    def _modify_molecule(self, modification_func):
        # Apply the modification and ensure it's valid
        mol = modification_func(self.current_molecule)
        if mol is not None:
            return mol
        return self.current_molecule

    def _add_aspirin_chain(self, mol):
        # Add an aspirin chain to the molecule
        try:
            mol = Chem.RWMol(mol)
            aspirin = Chem.MolFromSmiles('CC(=O)OC1=CC=CC=C1C(=O)O')
            mol = Chem.CombineMols(mol, aspirin)
            smi = AllChem.MolToSmiles(mol)
            return Chem.MolFromSmiles(smi)
        except ValueError:
            return None

    def _remove_aspirin_chain(self, mol):
        # Remove an aspirin chain from the molecule
        try:
            smi = Chem.MolToSmiles(mol)
            if 'CC(=O)OC1=CC=CC=C1C(=O)O' in smi:
                smi = smi.replace('CC(=O)OC1=CC=CC=C1C(=O)O', '', 1)
                return Chem.MolFromSmiles(smi)
            return None
        except ValueError:
            return None

    def _get_observation(self):
        return np.array(AllChem.GetMorganFingerprintAsBitVect(self.current_molecule, 2, nBits=100), dtype=np.float32)

    def _compute_reward(self):
        # Reward based on QED score
        try:
            qed_score = QED.qed(self.current_molecule)
            if qed_score > 0.5:  # Consider a QED score threshold for good molecules
                self.good_qed_molecules.append((Chem.MolToSmiles(self.current_molecule), qed_score))
            return qed_score
        except:
            return 0.0

    def _is_done(self):
        # Done if the molecule has more than 50 heavy atoms
        return self.current_molecule.GetNumHeavyAtoms() > 50

# %%
import gym
from gym import spaces
import numpy as np
from rdkit import Chem
from rdkit.Chem import AllChem, QED
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm

class MoleculeEnv(gym.Env):
    def __init__(self, data_path):
        super(MoleculeEnv, self).__init__()
        self.action_space = spaces.Discrete(4)  # Define 4 actions for simplicity
        self.observation_space = spaces.Box(low=0, high=1, shape=(100,), dtype=np.float32)
        self.current_molecule = None
        self.good_qed_molecules = []  # Track of molecules with good QED scores
        self.df = pd.read_csv(data_path)
        self._prepare_data()
        self.reset()

    def reset(self):
        self.current_molecule = Chem.MolFromSmiles('CC')  # Start with a simple ethane molecule
        return self._get_observation()

    def step(self, action):
        self._take_action(action)
        reward = self._compute_reward()
        done = self._is_done()
        obs = self._get_observation()
        return obs, reward, done, {}

    def _take_action(self, action):
        # Modify the molecule based on the action
        if action == 0:
            self.current_molecule = Chem.AddHs(self.current_molecule)  # Add hydrogen atoms
        elif action == 1:
            self.current_molecule = Chem.RemoveHs(self.current_molecule)  # Remove hydrogen atoms
        elif action == 2:
            self.current_molecule = self._modify_molecule(self._add_aspirin_chain)  # Add an aspirin chain
        elif action == 3:
            self.current_molecule = self._modify_molecule(self._remove_aspirin_chain)  # Remove an aspirin chain

    def _modify_molecule(self, modification_func):
        # Apply the modification and ensure it's valid
        mol = modification_func(self.current_molecule)
        if mol is not None:
            return mol
        return self.current_molecule

    def _add_aspirin_chain(self, mol):
        # Add an aspirin chain to the molecule
        try:
            mol = Chem.RWMol(mol)
            aspirin = Chem.MolFromSmiles('CC(=O)OC1=CC=CC=C1C(=O)O')
            mol = Chem.CombineMols(mol, aspirin)
            smi = AllChem.MolToSmiles(mol)
            return Chem.MolFromSmiles(smi)
        except ValueError:
            return None

    def _remove_aspirin_chain(self, mol):
        # Remove an aspirin chain from the molecule
        try:
            smi = Chem.MolToSmiles(mol)
            if 'CC(=O)OC1=CC=CC=C1C(=O)O' in smi:
                smi = smi.replace('CC(=O)OC1=CC=CC=C1C(=O)O', '', 1)
                return Chem.MolFromSmiles(smi)
            return None
        except ValueError:
            return None

    def _get_observation(self):
        return np.array(AllChem.GetMorganFingerprintAsBitVect(self.current_molecule, 2, nBits=100), dtype=np.float32)

    def _compute_reward(self):
        try:
            qed_score = QED.qed(self.current_molecule)
            # Get toxicity info for the current molecule
            molecule_smi = Chem.MolToSmiles(self.current_molecule)
            toxicity_info = self.get_toxicity_info(molecule_smi)
            if toxicity_info is None:
                return qed_score  # Return QED score if toxicity info is not available

            # Calculate total toxicity
            total_toxicity = self.calculate_total_toxicity(toxicity_info)

            # Define toxicity thresholds and corresponding rewards
            low_toxicity_threshold = 0.07
            high_toxicity_threshold = 0.18
            low_toxicity_reward = qed_score
            middle_toxicity_reward = -1 * total_toxicity
            high_toxicity_reward = -5

            # Apply reward based on toxicity level
            if total_toxicity < low_toxicity_threshold:
                return low_toxicity_reward
            elif low_toxicity_threshold <= total_toxicity <= high_toxicity_threshold:
                return middle_toxicity_reward
            else:
                return high_toxicity_reward
        except:
            return 0.0

    def _is_done(self):
        # Done if the molecule has more than 50 heavy atoms
        return self.current_molecule.GetNumHeavyAtoms() > 50

    def _prepare_data(self):
        # Convert string representations of lists to actual lists
        self.df['smiles_attention'] = self.df['smiles_attention'].apply(eval)
        self.df['smiles_token'] = self.df['smiles_token'].apply(eval)
        self.df['tox_location'] = self.df['tox_location'].apply(lambda x: tuple(sorted(eval(x))))

    def calculate_total_toxicity(self, toxicity_info):
        smiles_attention = toxicity_info['smiles_attention']
        tox_location = toxicity_info['tox_location']
        total_toxicity = sum(smiles_attention[i] for i in tox_location)
        return total_toxicity

    def get_toxicity_info(self, molecule_smi):
        row = self.df[self.df['molecule_smi'] == molecule_smi]
        if row.empty:
            return None
        toxicity_info = {
            'smiles_token': row['smiles_token'].values[0],
            'smiles_attention': row['smiles_attention'].values[0],
            'tox_location': row['tox_location'].values[0]
        }
        return toxicity_info

    def plot_attention_scores(self, toxicity_info):
        smiles_token = toxicity_info['smiles_token']
        smiles_attention = toxicity_info['smiles_attention']
        tox_location = toxicity_info['tox_location']

        fig, ax = plt.subplots(figsize=(10, 5))
        color_mapper_non_toxic = cm.Oranges
        color_mapper_toxic = cm.Greens
        colors = self._get_index_and_colors(smiles_attention, smiles_token, lambda x: True, tox_location, color_mapper_non_toxic, color_mapper_toxic)

        for index, token in enumerate(smiles_token):
            color = colors[index]
            ax.bar(index, smiles_attention[index], color=color, align='center')

        ax.set_xticks(range(len(smiles_token)))
        ax.set_xticklabels(smiles_token, rotation=90)
        ax.set_ylabel('Attention Score')
        ax.set_title('Attention Scores with Toxicity Highlighting')
        plt.show()

    def _get_index_and_colors(self, smi_att, smi_token, indexes, indexes_toxic, color_mapper_non_toxic, color_mapper_toxic):
        indices = []
        colors = {}
        for index, attention in enumerate(
            map(
                lambda t: t[0],
                filter(
                    lambda t: indexes(t),
                    zip(smi_att, smi_token)
                )
            )
        ):
            indices.append(index)
            if index in indexes_toxic:
                colors[index] = color_mapper_toxic(attention)
            else:
                colors[index] = color_mapper_non_toxic(attention)
        return colors

# Load the data and initialize the environment
data_path = '/Users/localadmin/Desktop/RL_FINAL/attention_scores.csv'
df = pd.read_csv(data_path)
for i in range(len(df)):
    df.at[i, 'smiles_attention'] = eval(df.at[i, 'smiles_attention'])
    df.at[i, 'smiles_token'] = eval(df.at[i, 'smiles_token'])
    df.at[i, 'tox_location'] = tuple(sorted(eval(df.at[i, 'tox_location'])))

# Initialize the environment with the dataframe
#env = MoleculeEnv(data_path)

# %%
class ActorCritic(tf.keras.Model):
    def __init__(self, action_space):
        super(ActorCritic, self).__init__()
        self.dense1 = layers.Dense(128, activation='relu')
        self.dense2 = layers.Dense(128, activation='relu')
        self.actor = layers.Dense(action_space, activation='softmax')
        self.critic = layers.Dense(1, activation='linear')

    def call(self, inputs):
        x = self.dense1(inputs)
        x = self.dense2(x)
        return self.actor(x), self.critic(x)

# %%
env = MoleculeEnv(data_path)
model = ActorCritic(action_space=env.action_space.n)
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
def compute_loss(action_probs, values, rewards):
    advantage = rewards - values
    actor_loss = -tf.math.log(action_probs) * advantage
    critic_loss = tf.square(advantage)
    return tf.reduce_mean(actor_loss + critic_loss)

@tf.function
def train_step(state, action, reward, next_state, done):
    state = tf.convert_to_tensor([state], dtype=tf.float32)
    next_state = tf.convert_to_tensor([next_state], dtype=tf.float32)
    action = tf.convert_to_tensor([action], dtype=tf.int32)
    reward = tf.convert_to_tensor([reward], dtype=tf.float32)
    done = tf.convert_to_tensor([done], dtype=tf.float32)

    with tf.GradientTape() as tape:
        action_probs, value = model(state)
        _, next_value = model(next_state)

        action_prob = tf.reduce_sum(action_probs * tf.one_hot(action, env.action_space.n), axis=1)
        td_target = reward + (1 - done) * next_value
        td_error = td_target - value
        loss = compute_loss(action_prob, value, reward)

    grads = tape.gradient(loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))

# %%
# num_episodes = 10
# for episode in range(num_episodes):
#     state = env.reset()
#     done = False
#     episode_reward = 0

#     while not done:
#         state = np.expand_dims(state, axis=0)
#         action_probs, _ = model(state)
#         action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
#         next_state, reward, done, _ = env.step(action)
#         train_step(state[0], action, reward, next_state, done)
#         state = next_state
#         episode_reward += reward

#     print(f'Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

# print("Training finished!")

# %%
# from rdkit import Chem

# # Inside the training loop
# num_episodes = 10
# unique_molecules = set()
# unique_molecule_details = []

# for episode in range(num_episodes):
#     state = env.reset()
#     done = False
#     episode_reward = 0

#     while not done:
#         state = np.expand_dims(state, axis=0)
#         action_probs, _ = model(state)
#         action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
#         next_state, reward, done, _ = env.step(action)
#         train_step(state[0], action, reward, next_state, done)
#         state = next_state
#         episode_reward += reward

#         # Calculate QED score of the current molecule
#         current_qed_score = env._compute_reward()  # QED score
#         current_smiles = Chem.MolToSmiles(env.current_molecule)

#         # Check if the current molecule is unique
#         if current_smiles not in unique_molecules:
#             unique_molecules.add(current_smiles)
#             unique_molecule_details.append((current_smiles, current_qed_score))

#     # Print episode statistics
#     print(f'Training Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

# # Print unique molecules with their QED values
# print("Unique molecules with their QED values:")
# for idx, (smiles, qed_score) in enumerate(unique_molecule_details, start=1):
#     print(f"Molecule {idx}: SMILES: {smiles}, QED Score: {qed_score}")

from rdkit import Chem

# Inside the training loop
num_episodes = 30
unique_molecules = set()
unique_molecule_details = []

for episode in range(num_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state = np.expand_dims(state, axis=0)
        action_probs, _ = model(state)
        action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
        next_state, reward, done, _ = env.step(action)
        train_step(state[0], action, reward, next_state, done)
        state = next_state
        episode_reward += reward

        # Calculate QED score of the current molecule
        current_qed_score = env._compute_reward()  # QED score
        current_smiles = Chem.MolToSmiles(env.current_molecule)

        # Check if the current molecule is unique
        if current_smiles not in unique_molecules:
            unique_molecules.add(current_smiles)
            unique_molecule_details.append((current_smiles, current_qed_score))

    # Print episode statistics
    print(f'Training Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

# Print unique molecules with their QED values
print("Unique molecules with their QED values:")
for idx, (smiles, qed_score) in enumerate(unique_molecule_details, start=1):
    print(f"Molecule {idx}: SMILES: {smiles}, QED Score: {qed_score}")
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function train_step at 0x161692160> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...

# %%
from rdkit import Chem
import matplotlib.pyplot as plt

# Inside the training loop
num_episodes = 30
unique_molecules = set()
unique_molecule_details = []

for episode in range(num_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state = np.expand_dims(state, axis=0)
        action_probs, _ = model(state)
        action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
        next_state, reward, done, _ = env.step(action)
        train_step(state[0], action, reward, next_state, done)
        state = next_state
        episode_reward += reward

        # Calculate QED score of the current molecule
        current_qed_score = env._compute_reward()  # QED score
        current_smiles = Chem.MolToSmiles(env.current_molecule)

        # Check if the current molecule is unique
        if current_smiles not in unique_molecules:
            unique_molecules.add(current_smiles)
            unique_molecule_details.append((current_smiles, current_qed_score))

    # Print episode statistics
    print(f'Training Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

# Print unique molecules with their QED values
print("Unique molecules with their QED values:")
for idx, (smiles, qed_score) in enumerate(unique_molecule_details, start=1):
    print(f"Molecule {idx}: SMILES: {smiles}, QED Score: {qed_score}")

# Plotting function
def plot_qed_scores(unique_molecule_details):
    episodes = list(range(1, len(unique_molecule_details) + 1))
    qed_scores = [details[1] for details in unique_molecule_details]

    plt.figure(figsize=(30, 6))
    plt.plot(episodes, qed_scores, marker='o', linestyle='-', color='b')
    plt.title('QED Scores of Unique Molecules Discovered During Training')
    plt.xlabel('Episode')
    plt.ylabel('QED Score')
    plt.xticks(episodes)
    plt.grid(True)
    plt.show()

# Call the plotting function
plot_qed_scores(unique_molecule_details)
# Out:
# Training Episode 1/30, Total Reward: 20.088701391293704
# Training Episode 2/30, Total Reward: 15.509304424500401
# Training Episode 3/30, Total Reward: 617.4764536443352
# Training Episode 4/30, Total Reward: 391.5136230002925
# Training Episode 5/30, Total Reward: 523.4355191904716
# Training Episode 6/30, Total Reward: 344.7503078747453
# Training Episode 7/30, Total Reward: 593.0216407212132
# Training Episode 8/30, Total Reward: 42.294841931370634
# Training Episode 9/30, Total Reward: 70.71685343812372
# Training Episode 10/30, Total Reward: 48.117104607384114
# Training Episode 11/30, Total Reward: 53.26599790161014
# Training Episode 12/30, Total Reward: 136.9775544333573
# Training Episode 13/30, Total Reward: 4.20349639755273
# Training Episode 14/30, Total Reward: 13.027027005057647
# Training Episode 15/30, Total Reward: 3.0485899451225826
# Training Episode 16/30, Total Reward: 3.972645255564034
# Training Episode 17/30, Total Reward: 3.916316584710521
# ...

# %%
from rdkit import Chem
import matplotlib.pyplot as plt

# Inside the training loop
num_episodes = 30
unique_molecules = set()
unique_molecule_details = []

for episode in range(num_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state = np.expand_dims(state, axis=0)
        action_probs, _ = model(state)
        action = np.random.choice(len(action_probs[0]), p=action_probs[0].numpy())
        next_state, reward, done, _ = env.step(action)
        train_step(state[0], action, reward, next_state, done)
        state = next_state
        episode_reward += reward

        # Calculate QED score of the current molecule
        current_qed_score = env._compute_reward()  # QED score
        current_smiles = Chem.MolToSmiles(env.current_molecule)

        # Check if the current molecule is unique
        if current_smiles not in unique_molecules:
            unique_molecules.add(current_smiles)
            unique_molecule_details.append((current_smiles, current_qed_score))

    # Print episode statistics
    print(f'Training Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

# Print unique molecules with their QED values
print("Unique molecules with their QED values:")
for idx, (smiles, qed_score) in enumerate(unique_molecule_details, start=1):
    print(f"Molecule {idx}: SMILES: {smiles}, QED Score: {qed_score}")

# Plotting function
def plot_qed_scores(unique_molecule_details):
    episodes = list(range(1, len(unique_molecule_details) + 1))
    qed_scores = [details[1] for details in unique_molecule_details]

    plt.figure(figsize=(10, 6))
    plt.plot(episodes, qed_scores, marker='o', linestyle='-', color='b')

    for i, (episode, qed_score) in enumerate(zip(episodes, qed_scores), start=1):
        plt.text(episode, qed_score, f'{i}', fontsize=12, ha='right')

    plt.title('QED Scores of Unique Molecules Discovered During Training')
    plt.xlabel('Molecule Number')
    plt.ylabel('QED Score')
    plt.xticks(episodes)
    plt.grid(True)
    plt.show()

# Call the plotting function
plot_qed_scores(unique_molecule_details)
# Out:
# Training Episode 1/30, Total Reward: 5.708098534739912
# Training Episode 2/30, Total Reward: 6.046909150513445
# Training Episode 3/30, Total Reward: 4.0143447376678845
# Training Episode 4/30, Total Reward: 3.9777949507105532
# Training Episode 5/30, Total Reward: 5.43849082768619
# Training Episode 6/30, Total Reward: 10.779148017295434
# Training Episode 7/30, Total Reward: 10.720244498868661
# Training Episode 8/30, Total Reward: 16.452945512637438
# Training Episode 9/30, Total Reward: 254.91472451545368
# Training Episode 10/30, Total Reward: 41.49473766185723
# Training Episode 11/30, Total Reward: 85.34888435044313
# Training Episode 12/30, Total Reward: 62.356128235333735
# Training Episode 13/30, Total Reward: 172.16403274280714
# Training Episode 14/30, Total Reward: 117.85057610205826
# Training Episode 15/30, Total Reward: 7.52180108297697
# Training Episode 16/30, Total Reward: 192.2406875616913
# Training Episode 17/30, Total Reward: 641.4640352153688
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import ast

# Function to calculate total toxicity
def calculate_total_toxicity(toxicity_info):
    smiles_attention = toxicity_info['smiles_attention']
    tox_location = toxicity_info['tox_location']
    total_toxicity = sum(smiles_attention[i] for i in tox_location)
    return total_toxicity

# Convert string representations of lists to actual lists using ast.literal_eval
for i in range(len(df)):
    df.at[i, 'smiles_attention'] = ast.literal_eval(str(df.at[i, 'smiles_attention']))
    df.at[i, 'smiles_token'] = ast.literal_eval(str(df.at[i, 'smiles_token']))
    df.at[i, 'tox_location'] = tuple(sorted(ast.literal_eval(str(df.at[i, 'tox_location']))))

# Print the first few rows of the dataframe to ensure it is loaded correctly
print(df.head())

def get_toxicity_info(df, molecule_smi):
    row = df[df['molecule_smi'] == molecule_smi]
    print(f"Searching for molecule: {molecule_smi}")
    print(f"Matching rows found: {len(row)}")
    if row.empty:
        return None
    toxicity_info = {
        'smiles_token': row['smiles_token'].values[0],
        'smiles_attention': row['smiles_attention'].values[0],
        'tox_location': row['tox_location'].values[0]
    }
    return toxicity_info

# Ensure the molecule_smi is correct and present in your data
molecule_smi = 'CCc1ccc(/C=C2/SC(=S)NC2=O)cc1'
toxicity_info = get_toxicity_info(df, molecule_smi)

# Print the toxicity info if found
if toxicity_info is None:
    print(f'Molecule {molecule_smi} not found in the data.')
else:
    print("Toxicity Info:")
    print(toxicity_info)

    # Calculate and print total toxicity
    total_toxicity = calculate_total_toxicity(toxicity_info)
    print(f"Total Toxicity: {total_toxicity}")

    def _get_index_and_colors(smi_att, smi_token, indexes, indexes_toxic, color_mapper_non_toxic, color_mapper_toxic):
        indices = []
        colors = {}
        for index, attention in enumerate(
            map(
                lambda t: t[0],
                filter(
                    lambda t: indexes(t),
                    zip(smi_att, smi_token)
                )
            )
        ):
            indices.append(index)
            if index in indexes_toxic:
                colors[index] = color_mapper_toxic(attention)
            else:
                colors[index] = color_mapper_non_toxic(attention)
        return colors

    def plot_attention_scores(toxicity_info):
        smiles_token = toxicity_info['smiles_token']
        smiles_attention = toxicity_info['smiles_attention']
        tox_location = toxicity_info['tox_location']

        fig, ax = plt.subplots(figsize=(10, 5))
        color_mapper_non_toxic = cm.Oranges
        color_mapper_toxic = cm.Greens
        colors = _get_index_and_colors(smiles_attention, smiles_token, lambda x: True, tox_location, color_mapper_non_toxic, color_mapper_toxic)

        for index, token in enumerate(smiles_token):
            color = colors[index]
            ax.bar(index, smiles_attention[index], color=color, align='center')

        ax.set_xticks(range(len(smiles_token)))
        ax.set_xticklabels(smiles_token, rotation=90)
        ax.set_ylabel('Attention Score')
        ax.set_title('Attention Scores with Toxicity Highlighting')
        plt.show()

    plot_attention_scores(toxicity_info)
# Out:
#    Unnamed: 0                                       molecule_smi  \
# 0           0  OC(=O)/C=C\C(O)=O.C[C@]12CC=C3[C@@H](CCC4=CC(=...
# 1           1     Cc1ccc(S(=O)(=O)N[C@@H](Cc2ccccc2)C(=O)CCl)cc1
# 2           2             FC1(F)Oc2c(cc(/C=C3\SC(=O)NC3=O)cc2)O1
# 3           3                      CCc1ccc(/C=C2/SC(=S)NC2=O)cc1
# 4           4                    CCN1/C(=C/C(C)=O)Sc2ccc(OC)cc21
#
#                                         smiles_token  \
# 0  [O, C, (, =, O, ), /, C, =, C, \, C, (, O, ), ...
# 1  [C, c, 1, c, c, c, (, S, (, =, O, ), (, =, O, ...
# 2  [F, C, 1, (, F, ), O, c, 2, c, (, c, c, (, /, ...
# 3  [C, C, c, 1, c, c, c, (, /, C, =, C, 2, /, S, ...
# 4  [C, C, N, 1, /, C, (, =, C, /, C, (, C, ), =, ...
#
#                                     smiles_attention  \
# 0  [0.002999250078573823, 0.0049645253457129, 0.0...
# 1  [0.009845857508480549, 0.012710891664028168, 0...
# 2  [0.00846217479556799, 0.008287838660180569, 0....
# ...

# %%
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import numpy as np

# Extract features and labels
def extract_features_and_labels(df):
    features = []
    labels = []
    for i, row in df.iterrows():
        mol = Chem.MolFromSmiles(row['molecule_smi'])
        if mol:
            fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024)
            features.append(fp)
            labels.append(sum(row['smiles_attention'][j] for j in row['tox_location']))
    return np.array(features), np.array(labels)

# Prepare dataset
features, labels = extract_features_and_labels(df)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.4f}')

# Example prediction
example_smiles = "[H]C([H])([H])C([H])([H])[H]"
example_mol = Chem.MolFromSmiles(example_smiles)
if example_mol:
    example_fp = np.array(AllChem.GetMorganFingerprintAsBitVect(example_mol, 2, nBits=1024))
    example_toxicity = model.predict([example_fp])[0]
    print(f"Predicted toxicity for {example_smiles}: {example_toxicity:.4f}")
# Out:
# Mean Squared Error: 0.0048
# Predicted toxicity for [H]C([H])([H])C([H])([H])[H]: 0.0989

# %%
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import pandas as pd
import numpy as np

# Load and process the dataset
data_path = '/Users/localadmin/Desktop/RL_FINAL/attention_scores.csv'
df = pd.read_csv(data_path)
df['smiles_attention'] = df['smiles_attention'].apply(ast.literal_eval)
df['smiles_token'] = df['smiles_token'].apply(ast.literal_eval)
df['tox_location'] = df['tox_location'].apply(lambda x: tuple(sorted(ast.literal_eval(x))))

# Extract features and labels
def extract_features_and_labels(df):
    features = []
    labels = []
    for i, row in df.iterrows():
        mol = Chem.MolFromSmiles(row['molecule_smi'])
        if mol:
            fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024)
            features.append(fp)
            labels.append(sum(row['smiles_attention'][j] for j in row['tox_location']))
    return np.array(features), np.array(labels)

# Prepare dataset
features, labels = extract_features_and_labels(df)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Train the model
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Evaluate the model
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse:.4f}')

# List of molecules
# molecules = [
#     "CC.CC(=O)Oc1ccccc1C(=O)O",
#     "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O",
#     "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O",
#     "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O",
#     "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]",
#     "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]",
#     "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]",
#     "[H]C([H])([H])C([H])([H])[H]"
# ]
# #for smiles in unique_molecule_details:
# for smiles,j in unique_molecule_details:
#   print(smiles)
# Predict toxicity for the list of molecules
idx = 1
for smiles,i in unique_molecule_details:
    mol = Chem.MolFromSmiles(smiles)
    if mol is not None:
        fp = np.array(AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024))
        toxicity = model.predict([fp])[0]
        print(f"Molecule {idx}: SMILES: {smiles}, Predicted Toxicity: {toxicity:.4f}")
    else:
        print(f"Molecule {idx}: SMILES: {smiles}, Invalid molecule")
    idx +=1
# Out:
# Mean Squared Error: 0.0048
# Molecule 1: SMILES: [H]C([H])([H])C([H])([H])[H], Predicted Toxicity: 0.0989
# Molecule 2: SMILES: CC.CC(=O)Oc1ccccc1C(=O)O, Predicted Toxicity: 0.0888
# Molecule 3: SMILES: [H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H], Predicted Toxicity: 0.0888
# Molecule 4: SMILES: CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O, Predicted Toxicity: 0.0888
# Molecule 5: SMILES: CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O, Predicted Toxicity: 0.0888
# Molecule 6: SMILES: [H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H], Predicted Toxicity: 0.0888
# Molecule 7: SMILES: CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O, Predicted Toxicity: 0.0888
# Molecule 8: SMILES: CC, Predicted Toxicity: 0.0989
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import AllChem
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Dummy environment and model for simulation
class DummyEnv:
    def reset(self):
        return np.random.rand(10)

    def step(self, action):
        next_state = np.random.rand(10)
        reward = np.random.rand() * 100
        done = np.random.rand() > 0.95
        info = {}
        return next_state, reward, done, info

    def _compute_reward(self):
        return np.random.rand()

    @property
    def current_molecule(self):
        return Chem.MolFromSmiles('CC(C)C(=O)O')

class DummyModel:
    def __call__(self, state):
        action_probs = np.random.rand(5)
        action_probs /= action_probs.sum()
        return action_probs, None

def train_step(state, action, reward, next_state, done):
    pass

# Simulated training loop
num_episodes = 30
episode_rewards = []
unique_molecule_details = []

env = DummyEnv()
model = DummyModel()

for episode in range(num_episodes):
    state = env.reset()
    done = False
    episode_reward = 0

    while not done:
        state = np.expand_dims(state, axis=0)
        action_probs, _ = model(state)
        action = np.random.choice(len(action_probs), p=action_probs)
        next_state, reward, done, _ = env.step(action)
        train_step(state[0], action, reward, next_state, done)
        state = next_state
        episode_reward += reward

        # Calculate QED score of the current molecule
        current_qed_score = env._compute_reward()  # QED score
        current_smiles = Chem.MolToSmiles(env.current_molecule)

        # Store molecule details
        unique_molecule_details.append((current_smiles, current_qed_score))

    # Collect episode reward
    episode_rewards.append(episode_reward)
    print(f'Training Episode {episode + 1}/{num_episodes}, Total Reward: {episode_reward}')

# Prepare data for toxicity prediction
molecule_smiles = [details[0] for details in unique_molecule_details]
qed_scores = [details[1] for details in unique_molecule_details]

# Dummy feature extraction for toxicity prediction
features = []
for smiles in molecule_smiles:
    mol = Chem.MolFromSmiles(smiles)
    if mol:
        fp = AllChem.GetMorganFingerprintAsBitVect(mol, 2, nBits=1024)
        features.append(list(fp))

# Split the data
X_train, X_test, y_train, y_test = train_test_split(features, qed_scores, test_size=0.2, random_state=42)

# Train RandomForest model
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)

# Predict toxicity
predicted_toxicity = rf_model.predict(features)

# Plot QED scores and toxicity over episodes
episodes = list(range(1, num_episodes + 1))
avg_qed_scores = [np.mean(qed_scores[:i+1]) for i in range(num_episodes)]
avg_toxicity = [np.mean(predicted_toxicity[:i+1]) for i in range(num_episodes)]

plt.figure(figsize=(12, 6))
plt.plot(episodes, avg_qed_scores, marker='o', linestyle='-', color='b', label='Average QED Score')
plt.plot(episodes, avg_toxicity, marker='s', linestyle='--', color='r', label='Average Predicted Toxicity')

for i in range(num_episodes):
    plt.text(episodes[i], avg_qed_scores[i], f'{i+1}', fontsize=12, ha='right')
    plt.text(episodes[i], avg_toxicity[i], f'{i+1}', fontsize=12, ha='right')

plt.title('QED Score and Predicted Toxicity Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Score')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Training Episode 1/10, Total Reward: 1179.899268771709
# Training Episode 2/10, Total Reward: 1454.227114532138
# Training Episode 3/10, Total Reward: 408.5469696877725
# Training Episode 4/10, Total Reward: 1465.583930425062
# Training Episode 5/10, Total Reward: 781.7885653031249
# Training Episode 6/10, Total Reward: 221.69564128479826
# Training Episode 7/10, Total Reward: 699.0609155635285
# Training Episode 8/10, Total Reward: 373.57827550423934
# Training Episode 9/10, Total Reward: 493.70971541263606
# Training Episode 10/10, Total Reward: 166.2125022911668

# %%
# Provided data
episode_rewards = [8.789816704338472, 12.08120155664919, 21.6342685103393, 20.297438828874135, 31.33649458417443, 81.51809470169796, 60.08721696181549, 51.02546004510516, 45.83664073450262, 72.82492493605825]
toxicity_data = [
    {"SMILES": "[H]C([H])([H])C([H])([H])[H]", "Predicted Toxicity": 0.0989},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC", "Predicted Toxicity": 0.0989},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888}
]

# Plotting
plt.figure(figsize=(12, 6))

# Plot episode rewards (assuming linear increase)
plt.plot(range(1, len(episode_rewards) + 1), episode_rewards, marker='o', linestyle='-', color='b', label='Episode Rewards')

# Plot predicted toxicity
toxicity_values = [entry["Predicted Toxicity"] for entry in toxicity_data]
plt.plot(range(1, len(toxicity_values) + 1), toxicity_values, marker='s', linestyle='--', color='r', label='Predicted Toxicity')

# Annotate episode numbers
for i, reward in enumerate(episode_rewards):
    plt.text(i + 1, reward, f'{i + 1}', fontsize=10, ha='right')
for i, entry in enumerate(toxicity_data):
    plt.text(i + 1, entry["Predicted Toxicity"], f'{i + 1}', fontsize=10, ha='right')

# Plot settings
plt.title('Episode Rewards and Predicted Toxicity Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Provided data
episode_rewards = [8.789816704338472, 12.08120155664919, 21.6342685103393, 20.297438828874135, 31.33649458417443, 81.51809470169796, 60.08721696181549, 51.02546004510516, 45.83664073450262, 72.82492493605825]
toxicity_data = [
    {"SMILES": "[H]C([H])([H])C([H])([H])[H]", "Predicted Toxicity": 0.0989},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC", "Predicted Toxicity": 0.0989},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888}
]

# Plotting
plt.figure(figsize=(10, 6))

# Plot predicted toxicity
toxicity_values = [entry["Predicted Toxicity"] for entry in toxicity_data]
plt.plot(range(1, len(toxicity_values) + 1), toxicity_values, marker='o', linestyle='--', color='r', label='Predicted Toxicity')

# Annotate molecule numbers
for i, entry in enumerate(toxicity_data):
    plt.text(i + 1, entry["Predicted Toxicity"], f'{i + 1}', fontsize=10, ha='right')

# Plot settings
plt.title('Predicted Toxicity Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Predicted Toxicity')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Provided data
episode_rewards = [
    5.708098534739912, 6.046909150513445, 4.0143447376678845, 3.9777949507105532, 5.43849082768619,
    10.779148017295434, 10.720244498868661, 16.452945512637438, 254.91472451545368, 41.49473766185723,
    85.34888435044313, 62.356128235333735, 172.16403274280714, 117.85057610205826, 7.52180108297697,
    192.2406875616913, 641.4640352153688, 174.40445281998697, 155.3488346191642, 35.69644028379506,
    86.62360197869847, 348.1642619654805, 279.9037606670152, 859.2917037699054, 390.4137033384145,
    821.1204117444399, 322.5262359640623, 61.68103230867928, 206.86093293781875, 38.3543757825145
]

toxicity_data = [
    {"SMILES": "[H]C([H])([H])C([H])([H])[H]", "Predicted Toxicity": 0.0989},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O.CC(=O)Oc1ccccc1C(=O)O", "Predicted Toxicity": 0.0888},
    {"SMILES": "CC", "Predicted Toxicity": 0.0989},
    {"SMILES": "[H]C([H])([H])C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H].[H]OC(=O)c1c([H])c([H])c([H])c([H])c1OC(=O)C([H])([H])[H]", "Predicted Toxicity": 0.0888}
]

# Plotting
plt.figure(figsize=(12, 6))

# Plot episode rewards (assuming linear increase)
plt.plot(range(1, len(episode_rewards) + 1), episode_rewards, marker='o', linestyle='-', color='b', label='Episode Rewards')

# Plot predicted toxicity
toxicity_values = [entry["Predicted Toxicity"] for entry in toxicity_data]
plt.plot(range(1, len(toxicity_values) + 1), toxicity_values, marker='s', linestyle='--', color='r', label='Predicted Toxicity')

# Annotate episode numbers for rewards
for i, reward in enumerate(episode_rewards):
    plt.text(i + 1, reward, f'{i + 1}', fontsize=10, ha='right')

# Annotate episode numbers for toxicity
for i, entry in enumerate(toxicity_data):
    plt.text(i + 1, entry["Predicted Toxicity"], f'{i + 1}', fontsize=10, ha='right')

# Plot settings
plt.title('Episode Rewards and Predicted Toxicity Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Value')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Provided data
episode_rewards = [
    5.708098534739912, 6.046909150513445, 4.0143447376678845, 3.9777949507105532, 5.43849082768619,
    10.779148017295434, 10.720244498868661, 16.452945512637438, 254.91472451545368, 41.49473766185723,
    85.34888435044313, 62.356128235333735, 172.16403274280714, 117.85057610205826, 7.52180108297697,
    192.2406875616913, 641.4640352153688, 174.40445281998697, 155.3488346191642, 35.69644028379506,
    86.62360197869847, 348.1642619654805, 279.9037606670152, 859.2917037699054, 390.4137033384145,
    821.1204117444399, 322.5262359640623, 61.68103230867928, 206.86093293781875, 38.3543757825145
]

# Plotting
plt.figure(figsize=(10, 6))

# Plot episode rewards
plt.plot(range(1, len(episode_rewards) + 1), episode_rewards, marker='o', linestyle='-', color='b')

# Annotate episode numbers
for i, reward in enumerate(episode_rewards):
    plt.text(i + 1, reward, f'{i + 1}', fontsize=10, ha='right')

# Plot settings
plt.title('Episode Rewards Over Episodes')
plt.xlabel('Episode')
plt.ylabel('Reward')
plt.grid(True)
plt.show()
